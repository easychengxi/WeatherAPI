# %%
# import the package and function
from wwo_hist import retrieve_hist_data

# set working directory to store output csv file(s)
import os
os.chdir(".")

FREQUENCY = 3
START_DATE = '01-JAN-2019'
END_DATE = '01-JAN-2020'
API_KEY = '6fae54baa7d74f9bbf033638211105'
LOCATION_LIST = ['Detroit','Chicago']

hist_weather_data = retrieve_hist_data(API_KEY,
                                LOCATION_LIST,
                                START_DATE,
                                END_DATE,
                                FREQUENCY,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Detroit
#
#
# Currently retrieving data for Detroit: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.129575
# Currently retrieving data for Detroit: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:02.210790
# Currently retrieving data for Detroit: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.572535
# Currently retrieving data for Detroit: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.677762
# Currently retrieving data for Detroit: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.793169
# Currently retrieving data for Detroit: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.896945
# Currently retrieving data for Detroit: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.271846
# Currently retrieving data for Detroit: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.351316
# Currently retrieving data for Detroit: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:10.695162
# Currently retrieving data for Detroit: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:11.791026
# Currently retrieving data for Detroit: from 2019-11-01 to 2019-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:13.126197
# Currently retrieving data for Detroit: from 2019-12-01 to 2019-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:14.465438
# Currently retrieving data for Detroit: from 2020-01-01 to 2020-01-01
# Time elapsed (hh:mm:ss.ms) 0:00:14.732169
#
#
# export Detroit completed!
#
#
#
#
# Retrieving weather data for Chicago
#
#
# Currently retrieving data for Chicago: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.186192
# Currently retrieving data for Chicago: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:02.414240
# Currently retrieving data for Chicago: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.526801
# Currently retrieving data for Chicago: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.684660
# Currently retrieving data for Chicago: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.036298
# Currently retrieving data for Chicago: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.107965
# Currently retrieving data for Chicago: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.221721
# Currently retrieving data for Chicago: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.377586
# Currently retrieving data for Chicago: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:10.519868
# Currently retrieving data for Chicago: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:11.641515
# Currently retrieving data for Chicago: from 2019-11-01 to 2019-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:12.781344
# Currently retrieving data for Chicago: from 2019-12-01 to 2019-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:13.935488
# Currently retrieving data for Chicago: from 2020-01-01 to 2020-01-01
# Time elapsed (hh:mm:ss.ms) 0:00:14.203422
#
#
# export Chicago completed!
